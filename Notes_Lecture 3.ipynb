# %% [markdown]
# LECTURE 3

# %% [markdown]
# String Formatting with % Operator (Interpolation Operator)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# F-strings (formatted string literals)
# - F-strings are the string-building tool recommended for general purposes because of
# their ease of use and their speed of execution.
# - Use the f (more common) or F prefix with the placeholders needed for the items for insertion
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Template

# %%
from string import Template
t1 = Template("Destination: $place.")
location = t1.substitute(place=input("Enter the destination: "))
print(location)

templ_string = 'Hey $name, there is a $error error!'
new_string = Template(templ_string).substitute(
  name=name, error=hex(errorno))
print(new_string)
# Out:
# Enter the destination: hk
# Destination: hk.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-931a85cccc69> in <cell line: 7>()
#       6 templ_string = 'Hey $name, there is a $error error!'
#       7 new_string = Template(templ_string).substitute(
# ----> 8     name=name, error=hex(errorno))
#       9 print(new_string)
#
# NameError: name 'name' is not defined
