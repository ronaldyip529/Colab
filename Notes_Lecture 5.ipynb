# %% [markdown]
# # Bulit-In Modules
#
# 1. Around 70 built-in functions
# 2. Perform a variety of useful task
# - compiling a source file into a code object
# - executing a code object
# - switching to the Python debugger
# 3. With no import statement required

# %%
import math
print(math.exp(2))
# Out:
# 7.38905609893065

# %%
import math
numbers = [5, 7, 11]
result = sum( [math.factorial(n) for n in numbers] )
print(result)
# Out:
# 39921960

# %%
import random
number = random.randint(1, 100)
number = random.randrange(10) # 0 – 9
number = random.randrange(5, 10) # 5 - 9
number = random.randrange(0, 100, 10) # 0, 10, 20, 30,….. 100
number = random.random() # 0.0 to 1.0 but not include 1.0
number = random.uniform(1.0, 10.0) # 1.0 to 10.0

# %% [markdown]
# DATE Function

# %%
import datetime
x = datetime.datetime(2023, 9, 22)
print(x)
print(datetime.datetime.now())
print(datetime.date.today())
# Out:
# 2023-09-22 00:00:00
# 2023-11-21 13:14:22.027235
# 2023-11-21

# %%
# strftime
import datetime
x = datetime.datetime(2018, 6, 1)
print(x.strftime("%B"))
# Out:
# June
